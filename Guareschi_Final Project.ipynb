# %% [markdown]
# Housing data - Zillow

# %%
#import the necessary libraries

import pandas as pd
import numpy as np
import plotly.express as px
import requests
import warnings
import folium
from geopy.distance import distance

# settings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", None)

# %% [markdown]
# Now, we are going to extract the data from a website. We need an api key to access the data. This can be obtained for free.
#
# https://app.scrapeak.com/dashboard/scrapers/zillow-scraper-api

# %%
def get_listings(api_key, listing_url):
    url = "https://app.scrapeak.com/v1/scrapers/zillow/listing"

    querystring = {
        "api_key": api_key,
        "url":listing_url
    }

    return requests.request("GET", url, params=querystring)

def get_property_detail(api_key, zpid):
    url = "https://app.scrapeak.com/v1/scrapers/zillow/property"

    querystring = {
        "api_key": api_key,
        "zpid":zpid
    }

    return requests.request("GET", url, params=querystring)

def get_zpid(api_key, street, city, state, zip_code=None):
    url = "https://app.scrapeak.com/v1/scrapers/zillow/zpidByAddress"

    querystring = {
        "api_key": api_key,
        "street": street,
        "city": city,
        "state": state,
        "zip_code":zip_code
    }

    return requests.request("GET", url, params=querystring)

# %%
api_key = "37471fc1-4636-4f56-86a7-948af18f2fb3"

# %%
# zillow search url
rent_listing_url = "https://www.zillow.com/los-angeles-ca/rentals/?searchQueryState=%7B%22pagination%22%3A%7B%7D%2C%22usersSearchTerm%22%3A%22Los%20Angeles%2C%20CA%22%2C%22mapBounds%22%3A%7B%22west%22%3A-119.21510774414062%2C%22east%22%3A-117.60835725585937%2C%22south%22%3A33.56570519655188%2C%22north%22%3A34.47400545884537%7D%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A12447%2C%22regionType%22%3A6%7D%5D%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%22sort%22%3A%7B%22value%22%3A%22days%22%7D%2C%22fsba%22%3A%7B%22value%22%3Afalse%7D%2C%22fsbo%22%3A%7B%22value%22%3Afalse%7D%2C%22nc%22%3A%7B%22value%22%3Afalse%7D%2C%22fore%22%3A%7B%22value%22%3Afalse%7D%2C%22cmsn%22%3A%7B%22value%22%3Afalse%7D%2C%22auc%22%3A%7B%22value%22%3Afalse%7D%2C%22ah%22%3A%7B%22value%22%3Atrue%7D%2C%22fr%22%3A%7B%22value%22%3Atrue%7D%7D%2C%22isListVisible%22%3Atrue%7D"

# get listings
rent_listing_response = get_listings(api_key, rent_listing_url)

# %%
# view all keys
print(rent_listing_response.json().keys())

# check if request is successful
print("Request success:", rent_listing_response.json()["is_success"])

# view count of properies returned in request
num_of_properties = rent_listing_response.json()["data"]["categoryTotals"]["cat1"]["totalResultCount"]
print("Count of properties:", num_of_properties)
# Out:
# dict_keys(['is_success', 'data', 'message'])
# Request success: True
# Count of properties: 8193

# %%
# view all listings
df_rent_listings = pd.json_normalize(rent_listing_response.json()["data"]["cat1"]["searchResults"]["mapResults"])
print("Number of rows:", len(df_rent_listings))
print("Number of columns:", len(df_rent_listings.columns))
df_rent_listings
# Out:
# Number of rows: 500
# Number of columns: 81
#                buildingId         lotId       price  minBeds  minBaths  \
# 0    34.087723--118.28199  2.196491e+09  $4,495+/mo      1.0       1.0
# 1                     NaN           NaN   $1,795/mo      NaN       NaN
# 2                     NaN           NaN   $1,850/mo      NaN       NaN
# 3                     NaN           NaN   $7,300/mo      NaN       NaN
# 4                     NaN           NaN   $1,450/mo      NaN       NaN
# ..                    ...           ...         ...      ...       ...
# 495                   NaN           NaN   $1,650/mo      NaN       NaN
# 496  34.055275--118.28785  1.004491e+09  $1,350+/mo      0.0       1.0
# 497  33.988613--118.47448  1.049494e+09  $1,945+/mo      0.0       1.0
# 498                   NaN           NaN   $2,650/mo      NaN       NaN
# 499                   NaN           NaN   $2,850/mo      NaN       NaN
#
#      minArea                              streetViewMetadataURL  \
# 0      900.0  https://maps.googleapis.com/maps/api/streetvie...
# 1        NaN  https://maps.googleapis.com/maps/api/streetvie...
# 2        NaN  https://maps.googleapis.com/maps/api/streetvie...
# 3        NaN  https://maps.googleapis.com/maps/api/streetvie...
# 4        NaN                                                NaN
# ..       ...                                                ...
# 495      NaN                                                NaN
# 496      NaN                                                NaN
# 497    350.0                                                NaN
# 498      NaN                                                NaN
# 499      NaN                                                NaN
#
#                                          streetViewURL  \
# 0    https://maps.googleapis.com/maps/api/streetvie...
# 1    https://maps.googleapis.com/maps/api/streetvie...
# 2    https://maps.googleapis.com/maps/api/streetvie...
# 3    https://maps.googleapis.com/maps/api/streetvie...
# 4                                                  NaN
# ..                                                 ...
# 495                                                NaN
# 496                                                NaN
# 497                                                NaN
# 498                                                NaN
# 499                                                NaN
#
#                                                 imgSrc           plid  \
# 0    https://maps.googleapis.com/maps/api/staticmap...  4gga97443qzxj
# 1    https://maps.googleapis.com/maps/api/staticmap...            NaN
# 2    https://maps.googleapis.com/maps/api/staticmap...            NaN
# 3    https://maps.googleapis.com/maps/api/staticmap...            NaN
# 4    https://photos.zillowstatic.com/fp/c4209322852...            NaN
# ..                                                 ...            ...
# 495  https://photos.zillowstatic.com/fp/0248aebe231...            NaN
# 496  https://photos.zillowstatic.com/fp/ed02d8c65db...  15vq5pfy61uyv
# 497  https://photos.zillowstatic.com/fp/061c4a11304...   mukkh5c0ey2z
# 498  https://photos.zillowstatic.com/fp/d7676939287...            NaN
# 499  https://photos.zillowstatic.com/fp/70117daba33...            NaN
#
#      isFeaturedListing  isShowcaseListing  unitCount  isHomeRec isBuilding  \
# 0                 True              False        2.0      False       True
# 1                 True              False        NaN      False        NaN
# 2                False              False        NaN      False        NaN
# 3                False              False        NaN      False        NaN
# 4                False              False        NaN      False        NaN
# ..                 ...                ...        ...        ...        ...
# 495               True              False        NaN      False        NaN
# 496               True              False        2.0      False       True
# 497              False              False        2.0      False       True
# 498               True              False        NaN      False        NaN
# 499               True              False        NaN      False        NaN
#
#                                  address  badgeInfo statusType  \
# 0      906 Hyperion Ave, Los Angeles, CA        NaN   FOR_RENT
# 1                                     --        NaN   FOR_RENT
# 2                                     --        NaN   FOR_RENT
# 3                                     --        NaN   FOR_RENT
# 4                                     --        NaN   FOR_RENT
# ..                                   ...        ...        ...
# 495                                   --        NaN   FOR_RENT
# 496  2743 San Marino St, Los Angeles, CA        NaN   FOR_RENT
# 497       14 Westminster Ave, Venice, CA        NaN   FOR_RENT
# 498                                   --        NaN   FOR_RENT
# 499                                   --        NaN   FOR_RENT
#
#              statusText listingType  isFavorite  \
# 0              For Rent                   False
# 1    Apartment for rent                   False
# 2    Apartment for rent                   False
# 3    Apartment for rent                   False
# 4    Apartment for rent                   False
# ..                  ...         ...         ...
# 495  Apartment for rent                   False
# 496             san2743                   False
# 497            For Rent                   False
# 498  Apartment for rent                   False
# 499  Apartment for rent                   False
#
#                                              detailUrl  has3DModel  \
# 0           /b/906-hyperion-ave-los-angeles-ca-9n2sWT/       False
# 1    /homedetails/523-S-Mariposa-Ave-APT-15-Los-Ang...       False
# 2    /homedetails/125-S-Avenue-53-30A-Los-Angeles-C...       False
# 3    /homedetails/1153-W-37th-Dr-1-Los-Angeles-CA-9...       False
# 4    /homedetails/648-N-Hobart-Blvd-APT-17-Los-Ange...       False
# ..                                                 ...         ...
# 495                     /b/lan8123-van-nuys-ca-9MZzk5/       False
# 496                  /b/san2743-los-angeles-ca-5YG3jj/       False
# 497            /b/14-westminster-ave-venice-ca-5j4Y2P/       False
# 498  /homedetails/5866-Bowcroft-St-UNIT-2-Los-Angel...       False
# 499  /homedetails/7235-Hollywood-Blvd-W417-Los-Ange...       False
#
#      hasAdditionalAttributions canSaveBuilding  timeOnZillow  \
# 0                        False            True        129722
# 1                        False             NaN        135035
# 2                        False             NaN        139514
# 3                        False             NaN        149600
# 4                        False             NaN        377446
# ..                         ...             ...           ...
# 495                      False             NaN      54816112
# 496                      False            True      54816665
# 497                      False           False      54902329
# 498                      False             NaN      54914417
# 499                      False             NaN      54926787
#
#      latLong.latitude  latLong.longitude        zpid priceLabel  beds  baths  \
# 0           34.087723        -118.281990         NaN        NaN   NaN    NaN
# 1           34.064630        -118.299560  2084350992      $1.8K   1.0    1.0
# 2           34.106285        -118.197556  2057843920      $1.9K   1.0    1.0
# 3           34.019302        -118.293260  2057843952      $7.3K   4.0    4.0
# 4           34.083107        -118.305440  2057843961      $1.5K   0.0    1.0
# ..                ...                ...         ...        ...   ...    ...
# 495         34.218224        -118.469960  2084080590      $1.7K   1.0    1.0
# 496         34.055275        -118.287850         NaN        NaN   NaN    NaN
# 497         33.988613        -118.474480         NaN        NaN   NaN    NaN
# 498         34.018890        -118.374950    20430784      $2.7K   2.0    1.5
# 499         34.102120        -118.347690  2058518996      $2.9K   2.0    2.0
#
#        area isUserClaimingOwner isUserConfirmedClaim visited  \
# 0       NaN                 NaN                  NaN     NaN
# 1     700.0               False                False   False
# 2     650.0               False                False   False
# 3    1372.0               False                False   False
# 4     450.0               False                False   False
# ..      ...                 ...                  ...     ...
# 495     NaN               False                False   False
# 496     NaN                 NaN                  NaN     NaN
# 497     NaN                 NaN                  NaN     NaN
# 498     NaN               False                False   False
# 499     NaN               False                False   False
#
#     shouldShowZestimateAsPrice    pgapt     sgapt hasVideo  \
# 0                          NaN      NaN       NaN      NaN
# 1                        False  ForRent  For Rent    False
# 2                        False  ForRent  For Rent    False
# 3                        False  ForRent  For Rent    False
# 4                        False  ForRent  For Rent    False
# ..                         ...      ...       ...      ...
# 495                      False  ForRent  For Rent    False
# 496                        NaN      NaN       NaN      NaN
# 497                        NaN      NaN       NaN      NaN
# 498                      False  ForRent  For Rent    False
# 499                      False  ForRent  For Rent    False
#
#         availabilityDate variableData.type variableData.text  \
# 0                    NaN               NaN               NaN
# 1                   None      TIME_ON_INFO     2 minutes ago
# 2                   None      TIME_ON_INFO     2 minutes ago
# 3    2023-08-10 00:00:00      TIME_ON_INFO     2 minutes ago
# 4                   None      TIME_ON_INFO     6 minutes ago
# ..                   ...               ...               ...
# 495  2023-05-12 00:00:00      TIME_ON_INFO      15 hours ago
# 496                  NaN               NaN               NaN
# 497                  NaN               NaN               NaN
# 498                 None      TIME_ON_INFO      15 hours ago
# 499                 None      TIME_ON_INFO      15 hours ago
#
#     variableData.data.isFresh  hdpData.homeInfo.zpid hdpData.homeInfo.zipcode  \
# 0                         NaN                    NaN                      NaN
# 1                        True           2.084351e+09                    90020
# 2                        True           2.057844e+09                    90042
# 3                        True           2.057844e+09                    90007
# 4                        True           2.057844e+09                    90004
# ..                        ...                    ...                      ...
# 495                      True           2.084081e+09                    91406
# 496                       NaN                    NaN                      NaN
# 497                       NaN                    NaN                      NaN
# 498                      True           2.043078e+07                    90016
# 499                      True           2.058519e+09                    90046
#
#     hdpData.homeInfo.city hdpData.homeInfo.state  hdpData.homeInfo.latitude  \
# 0                     NaN                    NaN                        NaN
# 1             Los Angeles                     CA                  34.064630
# 2             Los Angeles                     CA                  34.106285
# 3             Los Angeles                     CA                  34.019302
# 4             Los Angeles                     CA                  34.083107
# ..                    ...                    ...                        ...
# 495              Van Nuys                     CA                  34.218224
# 496                   NaN                    NaN                        NaN
# 497                   NaN                    NaN                        NaN
# 498           Los Angeles                     CA                  34.018890
# 499           Los Angeles                     CA                  34.102120
#
#      hdpData.homeInfo.longitude  hdpData.homeInfo.price  \
# 0                           NaN                     NaN
# 1                   -118.299560                  1795.0
# 2                   -118.197556                  1850.0
# 3                   -118.293260                  7300.0
# 4                   -118.305440                  1450.0
# ..                          ...                     ...
# 495                 -118.469960                  1650.0
# 496                         NaN                     NaN
# 497                         NaN                     NaN
# 498                 -118.374950                  2650.0
# 499                 -118.347690                  2850.0
#
#      hdpData.homeInfo.bathrooms  hdpData.homeInfo.bedrooms  \
# 0                           NaN                        NaN
# 1                           1.0                        1.0
# 2                           1.0                        1.0
# 3                           4.0                        4.0
# 4                           1.0                        0.0
# ..                          ...                        ...
# 495                         1.0                        1.0
# 496                         NaN                        NaN
# 497                         NaN                        NaN
# 498                         1.5                        2.0
# 499                         2.0                        2.0
#
#      hdpData.homeInfo.livingArea hdpData.homeInfo.homeType  \
# 0                            NaN                       NaN
# 1                          700.0                 APARTMENT
# 2                          650.0                 APARTMENT
# 3                         1372.0                 APARTMENT
# 4                          450.0                 APARTMENT
# ..                           ...                       ...
# 495                          NaN                 APARTMENT
# 496                          NaN                       NaN
# 497                          NaN                       NaN
# 498                          NaN                 APARTMENT
# 499                          NaN                 APARTMENT
#
#     hdpData.homeInfo.homeStatus  hdpData.homeInfo.daysOnZillow  \
# 0                           NaN                            NaN
# 1                      FOR_RENT                           -1.0
# 2                      FOR_RENT                           -1.0
# 3                      FOR_RENT                           -1.0
# 4                      FOR_RENT                           -1.0
# ..                          ...                            ...
# 495                    FOR_RENT                           -1.0
# 496                         NaN                            NaN
# 497                         NaN                            NaN
# 498                    FOR_RENT                           -1.0
# 499                    FOR_RENT                           -1.0
#
#     hdpData.homeInfo.isFeatured hdpData.homeInfo.shouldHighlight  \
# 0                           NaN                              NaN
# 1                          True                            False
# 2                         False                            False
# 3                         False                            False
# 4                         False                            False
# ..                          ...                              ...
# 495                        True                            False
# 496                         NaN                              NaN
# 497                         NaN                              NaN
# 498                        True                            False
# 499                        True                            False
#
#     hdpData.homeInfo.isRentalWithBasePrice  hdpData.homeInfo.rentZestimate  \
# 0                                      NaN                             NaN
# 1                                    False                          1984.0
# 2                                    False                             NaN
# 3                                    False                             NaN
# 4                                    False                             NaN
# ..                                     ...                             ...
# 495                                  False                          2094.0
# 496                                    NaN                             NaN
# 497                                    NaN                             NaN
# 498                                  False                          2695.0
# 499                                  False                          3374.0
#
#     hdpData.homeInfo.isUnmappable hdpData.homeInfo.isPreforeclosureAuction  \
# 0                             NaN                                      NaN
# 1                           False                                    False
# 2                           False                                    False
# 3                           False                                    False
# 4                           False                                    False
# ..                            ...                                      ...
# 495                         False                                    False
# 496                           NaN                                      NaN
# 497                           NaN                                      NaN
# 498                         False                                    False
# 499                         False                                    False
#
#     hdpData.homeInfo.homeStatusForHDP  hdpData.homeInfo.priceForHDP  \
# 0                                 NaN                           NaN
# 1                            FOR_RENT                        1795.0
# 2                            FOR_RENT                        1850.0
# 3                            FOR_RENT                        7300.0
# 4                            FOR_RENT                        1450.0
# ..                                ...                           ...
# 495                          FOR_RENT                        1650.0
# 496                               NaN                           NaN
# 497                               NaN                           NaN
# 498                          FOR_RENT                        2650.0
# 499                          FOR_RENT                        2850.0
#
#     hdpData.homeInfo.isNonOwnerOccupied hdpData.homeInfo.isPremierBuilder  \
# 0                                   NaN                               NaN
# 1                                  True                             False
# 2                                  True                             False
# 3                                  True                             False
# 4                                  True                             False
# ..                                  ...                               ...
# 495                                True                             False
# 496                                 NaN                               NaN
# 497                                 NaN                               NaN
# 498                                True                             False
# 499                                True                             False
#
#     hdpData.homeInfo.isZillowOwned hdpData.homeInfo.currency  \
# 0                              NaN                       NaN
# 1                            False                       USD
# 2                            False                       USD
# 3                            False                       USD
# 4                            False                       USD
# ..                             ...                       ...
# 495                          False                       USD
# 496                            NaN                       NaN
# 497                            NaN                       NaN
# 498                          False                       USD
# 499                          False                       USD
#
#     hdpData.homeInfo.country hdpData.homeInfo.unit hasImage  \
# 0                        NaN                   NaN      NaN
# 1                        USA                Apt 15      NaN
# 2                        USA                 # 30A      NaN
# 3                        USA                   # 1      NaN
# 4                        USA                Apt 17     True
# ..                       ...                   ...      ...
# 495                      USA                 Apt 8     True
# 496                      NaN                   NaN     True
# 497                      NaN                   NaN     True
# 498                      USA                Unit 2     True
# 499                      USA                # W417     True
#
#      hdpData.homeInfo.zestimate  hdpData.homeInfo.datePriceChanged  \
# 0                           NaN                                NaN
# 1                           NaN                                NaN
# 2                           NaN                                NaN
# 3                           NaN                                NaN
# 4                           NaN                                NaN
# ..                          ...                                ...
# 495                         NaN                                NaN
# 496                         NaN                                NaN
# 497                         NaN                                NaN
# 498                    565200.0                       1.681801e+12
# 499                         NaN                                NaN
#
#      hdpData.homeInfo.priceChange  hdpData.homeInfo.taxAssessedValue  \
# 0                             NaN                                NaN
# 1                             NaN                                NaN
# 2                             NaN                                NaN
# 3                             NaN                                NaN
# 4                             NaN                                NaN
# ..                            ...                                ...
# 495                           NaN                                NaN
# 496                           NaN                                NaN
# 497                           NaN                                NaN
# 498                        -145.0                           439341.0
# 499                           NaN                                NaN
#
#     buildingName hdpData.homeInfo.priceReduction badgeInfo.type  \
# 0            NaN                             NaN            NaN
# 1            NaN                             NaN            NaN
# 2            NaN                             NaN            NaN
# 3            NaN                             NaN            NaN
# 4            NaN                             NaN            NaN
# ..           ...                             ...            ...
# 495          NaN                             NaN            NaN
# 496      san2743                             NaN            NaN
# 497          NaN                             NaN            NaN
# 498          NaN                   $145 (Apr 18)            NaN
# 499          NaN                             NaN            NaN
#
#     badgeInfo.text  hdpData.homeInfo.videoCount
# 0              NaN                          NaN
# 1              NaN                          NaN
# 2              NaN                          NaN
# 3              NaN                          NaN
# 4              NaN                          NaN
# ..             ...                          ...
# 495            NaN                          NaN
# 496            NaN                          NaN
# 497            NaN                          NaN
# 498            NaN                          NaN
# 499            NaN                          NaN
#
# [500 rows x 81 columns]

# %%
# remove non-numeric characters from 'priceLabel' column
df_rent_listings['priceLabel'] = df_rent_listings['priceLabel'].str.replace(r'\D', '')

# convert 'priceLabel' column to numeric dtype
df_rent_listings['priceLabel'] = pd.to_numeric(df_rent_listings['priceLabel'])

df_rent_by_location = df_rent_listings.groupby(['latLong.latitude', 'latLong.longitude']).agg({'priceLabel': 'mean'}).reset_index()

# %%
center = (df_rent_by_location['latLong.latitude'].iloc[0], df_rent_by_location['latLong.longitude'].iloc[0])

filtered_rentals = []
for index, row in df_rent_listings.iterrows():
    property_location = (row['latLong.latitude'], row['latLong.longitude'])
    if distance(property_location, center).km <= 5:
        filtered_rentals.append(row)

# %%
df_filtered_rentals = pd.DataFrame(filtered_rentals)

# %%
map = folium.Map(location=[df_filtered_rentals['latLong.latitude'].iloc[0], df_filtered_rentals['latLong.longitude'].iloc[0]], zoom_start=10)

center = (df_filtered_rentals['latLong.latitude'].iloc[1], df_filtered_rentals['latLong.longitude'].iloc[1])
folium.Circle(location=center, radius=5000, color='red', fill=True, fill_color='red', opacity=0.2).add_to(map)

# %%
for index, row in df_filtered_rentals.iterrows(): 
    popup_text = "Average Rent: $" + str(round(row['priceLabel'], 2))
    folium.Marker(location=[row['latLong.latitude'], row['latLong.longitude']], popup=popup_text).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a3da58295dc629356885fae6a4484fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a3da58295dc629356885fae6a4484fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a3da58295dc629356885fae6a4484fe = L.map(
#                 &quot;map_1a3da58295dc629356885fae6a4484fe&quot;,
#                 {
#                     center: [33.712067, -118.29036],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d831daaed6c71bfb0f6a6a5004d3219c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1a3da58295dc629356885fae6a4484fe);
#
#
#             var circle_68858ad27fef1ff871a8f11b0e71ba35 = L.circle(
#                 [33.734886, -118.29325],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.2, &quot;radius&quot;: 5000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1a3da58295dc629356885fae6a4484fe);
#
#
#             var marker_50f129be9e4069536048c4117335f6d9 = L.marker(
#                 [33.712067, -118.29036],
#                 {}
#             ).addTo(map_1a3da58295dc629356885fae6a4484fe);
#
#
#         var popup_fc0bbf53ca2cf0ddc2d1819c2bafa217 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_271251650a338aff14e646d7a6eae637 = $(`&lt;div id=&quot;html_271251650a338aff14e646d7a6eae637&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Average Rent: $65.0&lt;/div&gt;`)[0];
#                 popup_fc0bbf53ca2cf0ddc2d1819c2bafa217.setContent(html_271251650a338aff14e646d7a6eae637);
#
#
#
#         marker_50f129be9e4069536048c4117335f6d9.bindPopup(popup_fc0bbf53ca2cf0ddc2d1819c2bafa217)
#         ;
#
#
#
#
#             var marker_506cb02b7b6e3601b3a5b410217ddea0 = L.marker(
#                 [33.734886, -118.29325],
#                 {}
#             ).addTo(map_1a3da58295dc629356885fae6a4484fe);
#
#
#         var popup_f9da090912a8d4f0a0a5812fe95b958e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e7f8e26c79c8389ec4b07f8637fb4f57 = $(`&lt;div id=&quot;html_e7f8e26c79c8389ec4b07f8637fb4f57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Average Rent: $25.0&lt;/div&gt;`)[0];
#                 popup_f9da090912a8d4f0a0a5812fe95b958e.setContent(html_e7f8e26c79c8389ec4b07f8637fb4f57);
#
#
#
#         marker_506cb02b7b6e3601b3a5b410217ddea0.bindPopup(popup_f9da090912a8d4f0a0a5812fe95b958e)
#         ;
#
#
#
#
#             var marker_74e926ce6ea9cfd89ada983617c54c89 = L.marker(
#                 [33.739525, -118.28092],
#                 {}
#             ).addTo(map_1a3da58295dc629356885fae6a4484fe);
#
#
#         var popup_129bf18720c9910b5badaef0a671bcfc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b096ef7bc6b5d29b8c0bbf6dced0150f = $(`&lt;div id=&quot;html_b096ef7bc6b5d29b8c0bbf6dced0150f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Average Rent: $nan&lt;/div&gt;`)[0];
#                 popup_129bf18720c9910b5badaef0a671bcfc.setContent(html_b096ef7bc6b5d29b8c0bbf6dced0150f);
#
#
#
#         marker_74e926ce6ea9cfd89ada983617c54c89.bindPopup(popup_129bf18720c9910b5badaef0a671bcfc)
#         ;
#
#
#
#
#             var marker_f1f39cdc2984ce98813c20ec2b16219f = L.marker(
#                 [33.739773, -118.28092],
#                 {}
#             ).addTo(map_1a3da58295dc629356885fae6a4484fe);
#
#
#         var popup_f59d90bf14fc28399d91b4fa213a7961 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1f1340f1d1230b1cfbe876e78160ab00 = $(`&lt;div id=&quot;html_1f1340f1d1230b1cfbe876e78160ab00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Average Rent: $38.0&lt;/div&gt;`)[0];
#                 popup_f59d90bf14fc28399d91b4fa213a7961.setContent(html_1f1340f1d1230b1cfbe876e78160ab00);
#
#
#
#         marker_f1f39cdc2984ce98813c20ec2b16219f.bindPopup(popup_f59d90bf14fc28399d91b4fa213a7961)
#         ;
#
#
#
#
#             var marker_9fa1835376974815a46640f1a4666b62 = L.marker(
#                 [33.741184, -118.28712],
#                 {}
#             ).addTo(map_1a3da58295dc629356885fae6a4484fe);
#
#
#         var popup_cb4c92a5612ac9c23

# %%
map.save('Final_map.html')
